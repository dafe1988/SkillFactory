# %%
import pandas as pd

football = pd.read_csv('/home/dafe/GitHub/SkillFactory/module_1/data_sf.xls')

football[(football.Position == 'GK')&
        (football.GKReflexes == football.GKReflexes.max())].Wage.mean() / football[(football.Position == 'GK')&
                                                                                  (football.GKHandling == football.GKHandling.max())].Wage.mean()
# Out:
# 2.765957446808511

# %%
small_df = football[football.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Germany      3
# Uruguay      3
# Argentina    3
# Belgium      3
# France       2
# Slovenia     1
# Portugal     1
# Brazil       1
# Poland       1
# Croatia      1
# Italy        1
# England      1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Germany', 'Uruguay', 'Argentina', 'Belgium', 'France',
#        'Slovenia', 'Portugal', 'Brazil', 'Poland', 'Croatia', 'Italy',
#        'England'],
#       dtype='object')

# %%
s.index[0]
# Индекс серии s — это уникальные значения, встречающиеся в исходной серии small_df['Nationality']
# Out:
# 'Spain'

# %%
len(s.index)
# количество уникальных значений исходной серии, 
# то есть количество национальностей, 
# которые встречаются в датафрейме small_df
# Out:
# 13

# %%
s['Germany']
# количество немецких футболистов в датасета, обращаемся по индексу
# Out:
# 3

# %%
s1 = football['Club'].value_counts()
display(s1)
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# Vissel Kobe          29
# Padova               29
# FC Emmen             29
#                      ..
# Olympiacos CFP        8
# Vitória Guimarães     7
# Dinamo Zagreb         7
# GD Chaves             7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
len(s1.index)
# Out:
# 650

# %%
# Подсчет количества значений в процентах
s = small_df['Nationality'].value_counts(normalize=True)
display(s)
# Out:
# Spain        0.16
# Germany      0.12
# Uruguay      0.12
# Argentina    0.12
# Belgium      0.12
# France       0.08
# Slovenia     0.04
# Portugal     0.04
# Brazil       0.04
# Poland       0.04
# Croatia      0.04
# Italy        0.04
# England      0.04
# Name: Nationality, dtype: float64

# %%
s2 = football['Position'].value_counts(normalize=True)
display(s2)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s = small_df['Wage'].value_counts()
display(s)
# Out:
# 205000    3
# 240000    2
# 355000    2
# 290000    1
# 200000    1
# 380000    1
# 420000    1
# 455000    1
# 225000    1
# 405000    1
# 260000    1
# 215000    1
# 125000    1
# 145000    1
# 94000     1
# 565000    1
# 340000    1
# 285000    1
# 300000    1
# 130000    1
# 315000    1
# Name: Wage, dtype: int64

# %%
small_df = football[football.columns[0:7]].head(25)

s = small_df['Wage'].value_counts(bins=4)

display(s)

display(s.index)

display(s.index[3])

display(s.index[3].left)

display(s.index[3].right)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
# IntervalIndex([(211750.0, 329500.0], (93528.999, 211750.0], (329500.0, 447250.0], (447250.0, 565000.0]],
#               closed='right',
#               dtype='interval[float64]')
# Interval(447250.0, 565000.0, closed='right')
# 447250.0
# 565000.0

# %%
display(small_df['Wage'] > s.index[3].left)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000

# %%
s3 = football['FKAccuracy'].value_counts(bins=5)
display(s3)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s4 = football['Nationality'].value_counts()
print(s4.index)
print(len(s4.index))
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Italy',
#        'Colombia', 'Japan', 'Brazil', 'China PR',
#        ...
#        'Grenada', 'Central African Rep.', 'Jordan', 'Philippines', 'Malta',
#        'Indonesia', 'Bermuda', 'Nicaragua', 'Oman', 'Andorra'],
#       dtype='object', length=156)
# 156

# %%
football['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Switzerland', 'Norway', 'DR Congo', 'Ukraine',
#        'Mexico', 'Czech Republic', 'Ivory Coast', 'Albania', 'Turkey',
#        'Ghana', 'Ecuador', 'Mali', 'Nigeria', 'Dominican Republic',
#        'Japan', 'Cameroon', 'Republic of Ireland', 'Romania',
#        'United States', 'Russia', 'Hungary', 'Iceland', 'Zimbabwe',
#        'Togo', 'Angola', 'Burkina Faso', 'Peru', 'Scotland', 'Venezuela',
#        'Estonia', 'Tunisia', 'Israel', 'Equatorial Guinea', 'New Zealand',
# ...

# %%
len(football['Nationality'].unique())
# Out:
# 156

# %%
football['Nationality'].nunique()
# Out:
# 156

# %%
len(football['Position'].value_counts())
# Out:
# 27

# %%
len(football['Position'].unique())
# Out:
# 27

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()

display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1     Germany            3
# 2     Uruguay            3
# 3   Argentina            3
# 4     Belgium            3
# 5      France            2
# 6    Slovenia            1
# 7    Portugal            1
# 8      Brazil            1
# 9      Poland            1
# 10    Croatia            1
# 11      Italy            1
# 12    England            1

# %%
s_df.columns = ['Nationality','Players Count']

display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Germany              3
# 2      Uruguay              3
# 3    Argentina              3
# 4      Belgium              3
# 5       France              2
# 6     Slovenia              1
# 7     Portugal              1
# 8       Brazil              1
# 9       Poland              1
# 10     Croatia              1
# 11       Italy              1
# 12     England              1

# %%
spains = football[football.Nationality == 'Spain']
spains['Wage'].value_counts(bins=4, normalize=True)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
football['Wage'].value_counts(bins=4, normalize=True)
# Out:
# (435.999, 142000.0]     0.993875
# (142000.0, 283000.0]    0.004730
# (283000.0, 424000.0]    0.001241
# (424000.0, 565000.0]    0.000155
# Name: Wage, dtype: float64

# %%
football[football.Club == 'Manchester United'].Nationality.nunique()
# Out:
# 13

# %%
football[football.Club == 'Juventus'].Name.unique()
# Out:
# array(['Cristiano Ronaldo', 'P. Dybala', 'G. Chiellini', 'Alex Sandro',
#        'Douglas Costa', 'L. Bonucci', 'M. Pjanić', 'M. Benatia',
#        'W. Szczęsny', 'S. Khedira', 'B. Matuidi', 'M. Mandžukić',
#        'L. Spinazzola', 'P. Beruatto'], dtype=object)

# %%
f1 = football[football.Nationality == 'Brazil']
f1[football.Club == 'Juventus'].Name.unique()
# Out:
# <ipython-input-29-85ee3fc60f59>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f1[football.Club == 'Juventus'].Name.unique()
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
football[football.Nationality == 'Brazil'][football.Club == 'Juventus'].Name.unique()
# Out:
# <ipython-input-43-a3cb87bbbba1>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   football[football.Nationality == 'Brazil'][football.Club == 'Juventus'].Name.unique()
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
football[football.Age > 35].Club.value_counts()
# Out:
# Hokkaido Consadole Sapporo    4
# Club Atlético Huracán         4
# Club Atlético Colón           3
# Estudiantes de La Plata       3
# Nagoya Grampus                3
#                              ..
# AC Ajaccio                    1
# Guadalajara                   1
# CD Tondela                    1
# Jagiellonia Białystok         1
# Sassuolo                      1
# Name: Club, Length: 212, dtype: int64

# %%
football[football.Nationality == 'Argentina'].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
football[football.Nationality == 'Spain'].Age.value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 19    0.047690
# 29    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 16    0.002981
# 39    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
football.groupby(['Club'])

# %%
football.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
grouped_df = football.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
football.groupby(['Club'])['Wage'].sum()
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
football.groupby(['Club'])['Wage'].sum().sort_values(ascending=False).head(5)
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
football.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# RCB     4711000
# LCB     3989000
# RW      3276000
# RCM     3241000
# LCM     3145000
# LW      2945000
# LS      1866000
# RDM     1557000
# RS      1537000
# LDM     1516000
# RF       714000
# LF       601000
# RWB      420000
# LAM      366000
# LWB      347000
# CF       248000
# RAM       59000
# Name: Wage, dtype: int64

# %%
football.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
football.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
football.loc[football['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
football.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %%
football.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
football.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg     92
# 1. FC Heidenheim 1846    86
# 1. FC Kaiserslautern     85
# 1. FC Köln               76
# 1. FC Magdeburg          86
#                          ..
# Zagłębie Sosnowiec       84
# Çaykur Rizespor          81
# Örebro SK                85
# Östersunds FK            88
# Śląsk Wrocław            85
# Name: Strength, Length: 650, dtype: int64

# %%
football.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    22
# 1. FC Kaiserslautern     29
# 1. FC Köln               31
# 1. FC Magdeburg          19
#                          ..
# Zagłębie Sosnowiec       28
# Çaykur Rizespor          39
# Örebro SK                34
# Östersunds FK            32
# Śląsk Wrocław            31
# Name: Balance, Length: 650, dtype: int64

# %%
task1 = football.groupby(['Club'])['Wage'].agg(['mean','median'])
display(task1)
# Out:
#                               mean  median
# Club
#  SSV Jahn Regensburg   3750.000000    3500
# 1. FC Heidenheim 1846  3800.000000    3000
# 1. FC Kaiserslautern   1434.782609    1000
# 1. FC Köln             9200.000000    4000
# 1. FC Magdeburg        4000.000000    4000
# ...                            ...     ...
# Zagłębie Sosnowiec     1080.000000    1000
# Çaykur Rizespor        5363.636364    4500
# Örebro SK              1384.615385    1000
# Östersunds FK          1950.000000    1000
# Śląsk Wrocław          2083.333333    2000
#
# [650 rows x 2 columns]

# %%
task1[task1['mean'] == task1['median']].count()
# Out:
# mean      52
# median    52
# dtype: int64

# %%
task1[task1['mean'] == task1['median']].sort_values(['mean'],ascending=False)
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# Sunderland               4000.0    4000
# CD Feirense              4000.0    4000
# 1. FC Magdeburg          4000.0    4000
# Northampton Town         2500.0    2500
# Stade Brestois 29        2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Pohang Steelers          2000.0    2000
# AJ Auxerre               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Philadelphia Union       2000.0    2000
# Kashiwa Reysol           2000.0    2000
# CD Tondela               2000.0    2000
# Benevento                2000.0    2000
# FC Metz                  1500.0    1500
# PAOK                     1000.0    1000
# Orlando Pirates          1000.0    1000
# Panathinaikos FC         1000.0    1000
# Patriotas Boyacá FC      1000.0    1000
# ...

# %%
task2 = football.groupby(['Club'])['Wage'].sum()
task2.loc['Chelsea']
# Out:
# 2035000

# %%
football_20 = football[football.Age == 20]
task3 = football_20.groupby(['Nationality'])[['Wage','Age']].max()
display(task3)
# Out:
#                     Wage  Age
# Nationality
# Afghanistan         1000   20
# Albania             2000   20
# Algeria             7000   20
# Antigua & Barbuda   1000   20
# Argentina          54000   20
# ...                  ...  ...
# United States       8000   20
# Uruguay             3000   20
# Venezuela           5000   20
# Wales              33000   20
# Zambia              6000   20
#
# [84 rows x 2 columns]

# %%
task3.loc['Argentina']
# Out:
# Wage    54000
# Age        20
# Name: Argentina, dtype: int64

# %%
football_30 = football[football.Age == 30]
task4 = football_30.groupby(['Nationality'])[['Wage','Age']].min()
display(task4)
# Out:
#               Wage  Age
# Nationality
# Albania       4000   30
# Algeria       4000   30
# Angola        2000   30
# Argentina     1000   30
# Armenia       5000   30
# ...            ...  ...
# Uruguay       2000   30
# Uzbekistan   17000   30
# Venezuela     8000   30
# Wales         2000   30
# Zimbabwe     11000   30
#
# [79 rows x 2 columns]

# %%
football[football.Club == 'FC Barcelona'][football.Nationality == 'Argentina'].Strength.max()
# Out:
# <ipython-input-117-7f3d78db05eb>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   football[football.Club == 'FC Barcelona'][football.Nationality == 'Argentina'].Strength.max()
# 59

# %%
football[football.Club == 'FC Barcelona'][football.Nationality == 'Argentina'].Balance.max()
# Out:
# <ipython-input-116-8cf112e5af7f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   football[football.Club == 'FC Barcelona'][football.Nationality == 'Argentina'].Balance.max()
# 95

# %%
pivot = football.loc[football['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
df2 = football.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
#       All                  580000.0
# Name: Belgium, dtype: float64

# %%
df = football
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
df3 = football.pivot_table(columns = 'Position', index = 'Club', values = 'Name', aggfunc = 'count', fill_value = 0, margins = True)
display(df3)
# Out:
# Position               CAM    CB  CDM  CF    CM    GK  LAM    LB  LCB  LCM  \
# Club
#  SSV Jahn Regensburg     0     5    1   0     2     3    0     2    0    0
# 1. FC Heidenheim 1846    1     3    0   0     1     2    0     2    1    0
# 1. FC Kaiserslautern     0     3    3   0     0     3    0     2    1    0
# 1. FC Köln               0     1    1   0     2     3    0     0    0    0
# 1. FC Magdeburg          0     4    0   1     0     3    0     1    1    1
# ...                    ...   ...  ...  ..   ...   ...  ...   ...  ...  ...
# Çaykur Rizespor          1     2    5   0     0     3    0     2    1    0
# Örebro SK                0     4    0   0     1     3    0     0    1    1
# Östersunds FK            1     1    0   1     3     3    0     2    1    1
# Śląsk Wrocław            0     1    3   0     1     3    0     2    1    0
# All                    633  1403  691  51  1067  1641    6  1002  409  233
#
# ...

# %%
df3['GK'].mean()
# Out:
# 2.5246153846153847

# %%
df3['CM'].value_counts()
# Out:
# 1       211
# 2       149
# 0       136
# 3        89
# 4        39
# 5        21
# 6         5
# 1067      1
# Name: CM, dtype: int64

# %%
df4 = football.pivot_table(columns = 'Nationality', index = 'Club', values = 'Wage', aggfunc = 'sum', fill_value = 0, margins = True)
display(df4)
# Out:
# Nationality            Afghanistan  Albania  Algeria  Andorra  Angola  \
# Club
#  SSV Jahn Regensburg             0        0        0        0       0
# 1. FC Heidenheim 1846            0        0        0        0       0
# 1. FC Kaiserslautern             0        0        0        0       0
# 1. FC Köln                       0        0        0        0       0
# 1. FC Magdeburg                  0        0        0        0       0
# ...                            ...      ...      ...      ...     ...
# Çaykur Rizespor                  0        0        0        0       0
# Örebro SK                        0     1000        0        0       0
# Östersunds FK                    0        0        0        0       0
# Śląsk Wrocław                    0        0        0        0       0
# All                           5000   172000   585000     1000   71000
#
# Nationality            Antigua & Barbuda  Argentina  Armenia  Australia  \
# Club
# ...

# %%
df4.loc['AS Monaco']['Russia']
# Out:
# 61000

# %%
df5 = football.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean', fill_value = 0, margins=True)
display(df5)
# Out:
# Position                     CAM         CB        CDM         CF         CM  \
# Club
#  SSV Jahn Regensburg    0.000000  46.600000  82.000000   0.000000  61.000000
# 1. FC Heidenheim 1846  68.000000  61.333333   0.000000   0.000000  68.000000
# 1. FC Kaiserslautern    0.000000  59.000000  65.666667   0.000000   0.000000
# 1. FC Köln              0.000000  60.000000  32.000000   0.000000  68.500000
# 1. FC Magdeburg         0.000000  60.000000   0.000000  64.000000   0.000000
# ...                          ...        ...        ...        ...        ...
# Çaykur Rizespor        74.000000  58.000000  62.800000   0.000000   0.000000
# Örebro SK               0.000000  60.750000   0.000000   0.000000  63.000000
# Östersunds FK          67.000000  76.000000   0.000000  77.000000  56.333333
# Śląsk Wrocław           0.000000  62.000000  66.666667   0.000000  72.000000
# All                    68.236967  57.734854  60.813314  69.803922  64.299906
#
# ...

# %%
df5['ST'].sort_values(ascending=False)
# Out:
# Club
# Vitória           91.000000
# Sydney FC         88.000000
# CD Lugo           87.000000
# Brøndby IF        84.666667
# Leicester City    84.500000
#                     ...
# BK Häcken          0.000000
# Spartak Moscow     0.000000
# BSC Young Boys     0.000000
# Benevento          0.000000
# FC Barcelona       0.000000
# Name: ST, Length: 651, dtype: float64

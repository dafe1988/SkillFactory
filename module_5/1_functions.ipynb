# %%
#  импортируем необходимые библиотеки для работы с массивами чисел и для визуализации
import numpy as np
import matplotlib.pyplot as plt
import math

# х - аргумент в нашей функции. 
# передадим начало и конец числового отрезка нашей функции и шаг аргумента:
x = np.arange(-10, 10.01, 0.01) # массив значений аргумента

# построение графика параболы
plt.plot(x, x**2) 

# включим сетку на графике 
plt.grid(True)

# показать график
plt.show()

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
1/(1+np.e**(-4))
# Out:
# 0.9820137900379085

# %%
x1=0.1
x2=0.3
x3=0.6
sig = 1/(1+np.e**(-2*(x1+x2+x3)))
sig
# Out:
# 0.8807970779778823

# %%
(2.1-1-1)**2+(2.9-1-3*1)**2+(4.1-1-5*1)**2
# Out:
# 4.830000000000002

# %%
-2.1-3*2.9-5*4.1
# Out:
# -31.299999999999997

# %%
f = np.array([8, 2, 8, 3, 5, 6, 5, 15])
h = np.arange(f.size)*7
np.gradient(f, h)
# Out:
# array([-0.85714286,  0.        ,  0.07142857, -0.21428571,  0.21428571,
#         0.        ,  0.64285714,  1.42857143])

# %%
np.gradient(f, 7)
# Out:
# array([-0.85714286,  0.        ,  0.07142857, -0.21428571,  0.21428571,
#         0.        ,  0.64285714,  1.42857143])

# %%
def rosen(x):
# Функция Розенброка
    return np.sum(100.0*(x[1:]-x[:-1]**2.0)**2.0 + (1-x[:-1])**2.0, axis=0)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# Настраиваем 3D график
fig = plt.figure(figsize=[15, 10])
ax = fig.gca(projection='3d')

# Задаем угол обзора
ax.view_init(45, 30)

# Создаем данные для графика
X = np.arange(-2, 2, 0.1)
Y = np.arange(-1, 3, 0.1)
X, Y = np.meshgrid(X, Y)
Z = rosen(np.array([X,Y]))

# Рисуем поверхность
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.show()

# %%
from scipy.optimize import minimize 
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(rosen, x0, method='powell',
    options={'xtol': 1e-8, 'disp': True})
print(res.x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 19
#          Function evaluations: 1622
# [1. 1. 1. 1. 1.]

# %%
from scipy.optimize import minimize
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(rosen, x0, method='nelder-mead',
    options={'xtol': 1e-8, 'disp': True})
print(res.x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 339
#          Function evaluations: 571
# [1. 1. 1. 1. 1.]

# %%
def draw_func(f):
    x = np.linspace(-10,10,1000)
    y = f(x)
    fig, ax = plt.subplots()
    ax.plot(x,y)

# %%
draw_func(lambda x: 1/(1+np.e**(-x)))

# %%
draw_func(lambda x: np.log(x))
# Out:
# <ipython-input-23-7294b41c3d7d>:1: RuntimeWarning: invalid value encountered in log
#   draw_func(lambda x: np.log(x))

# %%
draw_func(lambda x: np.e**x)

# %%
draw_func(lambda x: np.sin(x**2))

# %%
draw_func(lambda x: np.exp(x))

# %%
np.diff(1/(1+np.e**(-x)))
# Out:
# array([4.56235245e-07, 4.60820062e-07, 4.65450950e-07, ...,
#        4.65450950e-07, 4.60820062e-07, 4.56235245e-07])
